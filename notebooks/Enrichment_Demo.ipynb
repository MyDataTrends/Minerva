# %% [markdown]
# # Enrichment Demo
# This notebook shows a minimal example of running the semantic merge pipeline.

# %%
import pandas as pdfrom orchestrate_workflow import orchestrate_workflow
datalake = {f: pd.read_csv(f'datasets/{f}') for f in ['merge_df1.csv', 'merge_df2.csv']}result = orchestrate_workflow(user_id=1, file_name='sample_dataset.json', datalake_dfs=datalake)result['analysis']
